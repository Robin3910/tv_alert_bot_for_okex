# %% [markdown]
# # Get Started
# ## Install python package
# You can install `python-okx` from PyPi server.

# %%
! pip install python-okx --upgrade

# %% [markdown]
# ## Sign up as an OKX user
# Please refer to [Create account](https://www.okx.com/account/register)

# %% [markdown]
# ## Create API Key
# Please refer to [Create API Key](https://www.okx.com/account/my-api)

# %% [markdown]
# ## Import API modules
# The following modules are available
# - Trade
# - BlockTrading
# - Funding
# - Account
# - Convert
# - Earning
# - SubAccount
# - MarketData
# - PublicData
# - TradingData
# - Status
# - NDBroker
# - FDBroker

# %%
import okx.Trade as Trade

# %% [markdown]
# ## Fill in your API key details

# %%
api_key = "xxx"
secret_key = "xxx"
passphrase = "xxx"

# %% [markdown]
# ## Get available funds

# %%
import okx.Funding as Funding

flag = "1"  # live trading: 0, demo trading: 1

fundingAPI = Funding.FundingAPI(api_key, secret_key, passphrase, False, flag)

result = fundingAPI.get_currencies()
print(result)
# Out:
# 2024-12-12 11:13:07.149 | DEBUG    | okx.utils:pre_hash:18 - body:
# 2024-12-12 11:13:07.150 | DEBUG    | okx.utils:get_header:31 - header: {'Content-Type': 'application/json', 'OK-ACCESS-KEY': '80791c49-301a-401e-9e5a-5ec357eaacc9', 'OK-ACCESS-SIGN': b'hKMpuwBGsAzxb+wKpIOAs5iGQq3mdLxNWSOe675MZtM=', 'OK-ACCESS-TIMESTAMP': '2024-12-12T03:13:07.149Z', 'OK-ACCESS-PASSPHRASE': 'Robin3910!', 'x-simulated-trading': '1'}
# 2024-12-12 11:13:07.150 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:13:07.150 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/asset/currencies
# 2024-12-12 11:13:07.151 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '50038', 'data': [], 'msg': 'This feature is unavailable in demo trading'}

# %% [markdown]
# ## Get market data

# %%
import okx.MarketData as MarketData

flag = "1"  # live trading: 0, demo trading: 1

marketDataAPI = MarketData.MarketAPI(flag=flag)

result = marketDataAPI.get_tickers(instType="SPOT")
print(result)
# Out:
# 2024-12-12 11:13:35.176 | DEBUG    | okx.utils:get_header_no_sign:39 - header: {'Content-Type': 'application/json', 'x-simulated-trading': '1'}
# 2024-12-12 11:13:35.177 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:13:35.177 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/market/tickers?instType=SPOT
# 2024-12-12 11:13:35.178 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '0', 'msg': '', 'data': [{'instType': 'SPOT', 'instId': 'BOME-USDC', 'last': '0.005', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.005', 'high24h': '0.005', 'low24h': '0.005', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973176014', 'sodUtc0': '0.005', 'sodUtc8': '0.005'}, {'instType': 'SPOT', 'instId': 'OAS-USDT', 'last': '0.04438', 'lastSz': '120.39', 'askPx': '0.04438', 'askSz': '1676763.37', 'bidPx': '0.04431', 'bidSz': '1336924.56', 'open24h': '0.0403', 'high24h': '0.04438', 'low24h': '0.03991', 'volCcy24h': '903225.1160524', 'vol24h': '21283466.52', 'ts': '1733973212811', 'sodUtc0': '0.04438', 'sodUtc8': '0.04348'}, {'instType': 'SPOT', 'instId': 'LINK-BTC', 'last': '0.0001762', 'lastSz': '4583.14', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.0001762', 'high24h': '0.0001762', 'low24h': '0.0001762', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973198013', 'sodUtc0': '0.0001762', 'sodUtc8': '0.0001762'}, {'instType': 'SPOT', 'instId': 'KNC-USDT', 'last': '0.7063', 'lastSz': '31640.023305', 'askPx': '0.7062', 'askSz': '4316.647742', 'bidPx': '0.706', 'bidSz': '30203.256478', 'open24h': '0.6392', 'high24h': '0.7067', 'low24h': '0.6278', 'volCcy24h': '9493082.7282119192', 'vol24h': '14175378.772791', 'ts': '1733973213812', 'sodUtc0': '0.6877', 'sodUtc8': '0.691'}, {'instType': 'SPOT', 'instId': 'IOTA-USDC', 'last': '0.1302', 'lastSz': '4.123223', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1302', 'high24h': '0.1302', 'low24h': '0.1302', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973180013', 'sodUtc0': '0.1302', 'sodUtc8': '0.1302'}, {'instType': 'SPOT', 'instId': 'MASK-ETH', 'last': '0.1', 'lastSz': '82.3726', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1', 'high24h': '0.1', 'low24h': '0.1', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973180017', 'sodUtc0': '0.1', 'sodUtc8': '0.1'}, {'instType': 'SPOT', 'instId': 'MDT-USDC', 'last': '0.02', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.02', 'high24h': '0.02', 'low24h': '0.02', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973176014', 'sodUtc0': '0.02', 'sodUtc8': '0.02'}, {'instType': 'SPOT', 'instId': 'AXS-HKD', 'last': '50', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '50', 'high24h': '50', 'low24h': '50', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973177015', 'sodUtc0': '50', 'sodUtc8': '50'}, {'instType': 'SPOT', 'instId': 'BOME-USDT', 'last': '0.013', 'lastSz': '129377', 'askPx': '', 'askSz': '0', 'bidPx': '0.013', 'bidSz': '4864596', 'open24h': '0.013', 'high24h': '0.013', 'low24h': '0.013', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973197021', 'sodUtc0': '0.013', 'sodUtc8': '0.013'}, {'instType': 'SPOT', 'instId': 'LUNA-USDT', 'last': '0.5951', 'lastSz': '99291.697694', 'askPx': '0.5949', 'askSz': '97514.160707', 'bidPx': '0.5947', 'bidSz': '112209.270673', 'open24h': '0.5393', 'high24h': '0.596', 'low24h': '0.5249', 'volCcy24h': '41238288.0143000669', 'vol24h': '73590488.767866', 'ts': '1733973212911', 'sodUtc0': '0.5705', 'sodUtc8': '0.5758'}, {'instType': 'SPOT', 'instId': 'XEM-ETH', 'last': '0.0000361', 'lastSz': '468.527', 'askPx': '', 'askSz': '0', 'bidPx': '0.0000361', 'bidSz': '71526.59', 'open24h': '0.0000361', 'high24h': '0.0000361', 'low24h': '0.0000361', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973197020', 'sodUtc0': '0.0000361', 'sodUtc8': '0.0000361'}, {'instType': 'SPOT', 'instId': 'FRONT-DAI', 'last': '', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '', 'high24h': '', 'low24h': '', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973182016', 'sodUtc0': '', 'sodUtc8': ''}, {'instType': 'SPOT', 'instId': 'MEME-BTC', 'last': '0.5', 'lastSz': '100', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.5', 'high24h': '0.5', 'low24h': '0.5', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973180015', 'sodUtc0': '0.5', 'sodUtc8' ...

# %% [markdown]
# ## Handle errors

# %% [markdown]
# You will the error code `51000` when. you run the following code. More details about the error code can be found in `msg`.
# Please refer to  [error code](https://www.okx.com/docs-v5/en/#error-code) for addtional information.

# %%
import okx.MarketData as MarketData

flag = "1"  # live trading: 0, demo trading: 1

marketDataAPI = MarketData.MarketAPI(flag=flag)

result = marketDataAPI.get_tickers( instType="SPOT")
print(result)
# Out:
# 2024-12-12 11:13:48.289 | DEBUG    | okx.utils:get_header_no_sign:39 - header: {'Content-Type': 'application/json', 'x-simulated-trading': '1'}
# 2024-12-12 11:13:48.289 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:13:48.290 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/market/tickers?instType=SPOT
# 2024-12-12 11:13:48.290 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '0', 'msg': '', 'data': [{'instType': 'SPOT', 'instId': 'BOME-USDC', 'last': '0.005', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.005', 'high24h': '0.005', 'low24h': '0.005', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973176014', 'sodUtc0': '0.005', 'sodUtc8': '0.005'}, {'instType': 'SPOT', 'instId': 'OAS-USDT', 'last': '0.04438', 'lastSz': '120.39', 'askPx': '0.04438', 'askSz': '1676763.37', 'bidPx': '0.04431', 'bidSz': '1335855.41', 'open24h': '0.0403', 'high24h': '0.04438', 'low24h': '0.03991', 'volCcy24h': '903225.1160524', 'vol24h': '21283466.52', 'ts': '1733973227811', 'sodUtc0': '0.04438', 'sodUtc8': '0.04348'}, {'instType': 'SPOT', 'instId': 'LINK-BTC', 'last': '0.0001762', 'lastSz': '4583.14', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.0001762', 'high24h': '0.0001762', 'low24h': '0.0001762', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973198013', 'sodUtc0': '0.0001762', 'sodUtc8': '0.0001762'}, {'instType': 'SPOT', 'instId': 'KNC-USDT', 'last': '0.7063', 'lastSz': '31640.023305', 'askPx': '0.7061', 'askSz': '39051.97731', 'bidPx': '0.7057', 'bidSz': '41353.821043', 'open24h': '0.6392', 'high24h': '0.7067', 'low24h': '0.6278', 'volCcy24h': '9493082.7282119192', 'vol24h': '14175378.772791', 'ts': '1733973223912', 'sodUtc0': '0.6877', 'sodUtc8': '0.691'}, {'instType': 'SPOT', 'instId': 'IOTA-USDC', 'last': '0.1302', 'lastSz': '4.123223', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1302', 'high24h': '0.1302', 'low24h': '0.1302', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973180013', 'sodUtc0': '0.1302', 'sodUtc8': '0.1302'}, {'instType': 'SPOT', 'instId': 'MASK-ETH', 'last': '0.1', 'lastSz': '82.3726', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.1', 'high24h': '0.1', 'low24h': '0.1', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973180017', 'sodUtc0': '0.1', 'sodUtc8': '0.1'}, {'instType': 'SPOT', 'instId': 'MDT-USDC', 'last': '0.02', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.02', 'high24h': '0.02', 'low24h': '0.02', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973176014', 'sodUtc0': '0.02', 'sodUtc8': '0.02'}, {'instType': 'SPOT', 'instId': 'AXS-HKD', 'last': '50', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '50', 'high24h': '50', 'low24h': '50', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973177015', 'sodUtc0': '50', 'sodUtc8': '50'}, {'instType': 'SPOT', 'instId': 'BOME-USDT', 'last': '0.013', 'lastSz': '129377', 'askPx': '', 'askSz': '0', 'bidPx': '0.013', 'bidSz': '4864596', 'open24h': '0.013', 'high24h': '0.013', 'low24h': '0.013', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973197021', 'sodUtc0': '0.013', 'sodUtc8': '0.013'}, {'instType': 'SPOT', 'instId': 'LUNA-USDT', 'last': '0.5951', 'lastSz': '99291.697694', 'askPx': '0.5948', 'askSz': '98576.629193', 'bidPx': '0.5944', 'bidSz': '130758.265898', 'open24h': '0.5393', 'high24h': '0.596', 'low24h': '0.5249', 'volCcy24h': '41238288.0143000669', 'vol24h': '73590488.767866', 'ts': '1733973220711', 'sodUtc0': '0.5705', 'sodUtc8': '0.5758'}, {'instType': 'SPOT', 'instId': 'XEM-ETH', 'last': '0.0000361', 'lastSz': '468.527', 'askPx': '', 'askSz': '0', 'bidPx': '0.0000361', 'bidSz': '71526.59', 'open24h': '0.0000361', 'high24h': '0.0000361', 'low24h': '0.0000361', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973197020', 'sodUtc0': '0.0000361', 'sodUtc8': '0.0000361'}, {'instType': 'SPOT', 'instId': 'FRONT-DAI', 'last': '', 'lastSz': '0', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '', 'high24h': '', 'low24h': '', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973182016', 'sodUtc0': '', 'sodUtc8': ''}, {'instType': 'SPOT', 'instId': 'MEME-BTC', 'last': '0.5', 'lastSz': '100', 'askPx': '', 'askSz': '0', 'bidPx': '', 'bidSz': '0', 'open24h': '0.5', 'high24h': '0.5', 'low24h': '0.5', 'volCcy24h': '0', 'vol24h': '0', 'ts': '1733973180015', 'sodUtc0': '0.5', 'sodUtc8 ...

# %% [markdown]
# # Prepare for trading
# - Make sure you understand the basic trading rules. Please refer to [Basic Trading Rules](https://www.okx.com/support/hc/en-us/sections/360011507312)
# - Make sure you have enough funds in your trading account。Please refer to  [Get balance](https://www.okx.com/docs-v5/en/#rest-api-account-get-balance).

# %% [markdown]
# ## Get account balance. Please refer to  [Get balance](https://www.okx.com/docs-v5/en/#rest-api-account-get-balance).

# %%
import okx.Account as Account
flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)

result = accountAPI.get_account_balance()
print(result)
# Out:
# 2024-12-12 11:13:53.531 | DEBUG    | okx.utils:pre_hash:18 - body:
# 2024-12-12 11:13:53.533 | DEBUG    | okx.utils:get_header:31 - header: {'Content-Type': 'application/json', 'OK-ACCESS-KEY': '80791c49-301a-401e-9e5a-5ec357eaacc9', 'OK-ACCESS-SIGN': b'HWLEPLwAMSOz1zVTuxh8fEJYhlztt/0jxVVorOMEC1M=', 'OK-ACCESS-TIMESTAMP': '2024-12-12T03:13:53.531Z', 'OK-ACCESS-PASSPHRASE': 'Robin3910!', 'x-simulated-trading': '1'}
# 2024-12-12 11:13:53.534 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:13:53.535 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/account/balance
# 2024-12-12 11:13:53.536 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '0', 'data': [{'adjEq': '', 'borrowFroz': '', 'details': [{'accAvgPx': '', 'availBal': '3', 'availEq': '', 'borrowFroz': '', 'cashBal': '3', 'ccy': 'BTC', 'clSpotInUseAmt': '', 'crossLiab': '', 'disEq': '298097.478', 'eq': '3', 'eqUsd': '304181.1', 'fixedBal': '0', 'frozenBal': '0', 'imr': '', 'interest': '', 'isoEq': '0', 'isoLiab': '', 'isoUpl': '', 'liab': '', 'maxLoan': '', 'maxSpotInUse': '', 'mgnRatio': '', 'mmr': '', 'notionalLever': '', 'openAvgPx': '', 'ordFrozen': '0', 'rewardBal': '', 'smtSyncEq': '0', 'spotBal': '', 'spotCopyTradingEq': '0', 'spotInUseAmt': '', 'spotIsoBal': '0', 'spotUpl': '', 'spotUplRatio': '', 'stgyEq': '0', 'totalPnl': '', 'totalPnlRatio': '', 'twap': '0', 'uTime': '1651306734742', 'upl': '', 'uplLiab': ''}, {'accAvgPx': '', 'availBal': '9000', 'availEq': '', 'borrowFroz': '', 'cashBal': '9000', 'ccy': 'TUSD', 'clSpotInUseAmt': '', 'crossLiab': '', 'disEq': '0', 'eq': '9000', 'eqUsd': '90664.1324415', 'fixedBal': '0', 'frozenBal': '0', 'imr': '', 'interest': '', 'isoEq': '0', 'isoLiab': '', 'isoUpl': '', 'liab': '', 'maxLoan': '', 'maxSpotInUse': '', 'mgnRatio': '', 'mmr': '', 'notionalLever': '', 'openAvgPx': '', 'ordFrozen': '0', 'rewardBal': '', 'smtSyncEq': '0', 'spotBal': '', 'spotCopyTradingEq': '0', 'spotInUseAmt': '', 'spotIsoBal': '0', 'spotUpl': '', 'spotUplRatio': '', 'stgyEq': '0', 'totalPnl': '', 'totalPnlRatio': '', 'twap': '0', 'uTime': '1651306734794', 'upl': '', 'uplLiab': ''}, {'accAvgPx': '', 'availBal': '15', 'availEq': '', 'borrowFroz': '', 'cashBal': '15', 'ccy': 'ETH', 'clSpotInUseAmt': '', 'crossLiab': '', 'disEq': '57007.629', 'eq': '15', 'eqUsd': '58171.05', 'fixedBal': '0', 'frozenBal': '0', 'imr': '', 'interest': '', 'isoEq': '0', 'isoLiab': '', 'isoUpl': '', 'liab': '', 'maxLoan': '', 'maxSpotInUse': '', 'mgnRatio': '', 'mmr': '', 'notionalLever': '', 'openAvgPx': '', 'ordFrozen': '0', 'rewardBal': '', 'smtSyncEq': '0', 'spotBal': '', 'spotCopyTradingEq': '0', 'spotInUseAmt': '', 'spotIsoBal': '0', 'spotUpl': '', 'spotUplRatio': '', 'stgyEq': '0', 'totalPnl': '', 'totalPnlRatio': '', 'twap': '0', 'uTime': '1651306734794', 'upl': '', 'uplLiab': ''}, {'accAvgPx': '', 'availBal': '1500', 'availEq': '', 'borrowFroz': '', 'cashBal': '1500', 'ccy': 'UNI', 'clSpotInUseAmt': '', 'crossLiab': '', 'disEq': '22403.025', 'eq': '1500', 'eqUsd': '26356.500000000004', 'fixedBal': '0', 'frozenBal': '0', 'imr': '', 'interest': '', 'isoEq': '0', 'isoLiab': '', 'isoUpl': '', 'liab': '', 'maxLoan': '', 'maxSpotInUse': '', 'mgnRatio': '', 'mmr': '', 'notionalLever': '', 'openAvgPx': '', 'ordFrozen': '0', 'rewardBal': '', 'smtSyncEq': '0', 'spotBal': '', 'spotCopyTradingEq': '0', 'spotInUseAmt': '', 'spotIsoBal': '0', 'spotUpl': '', 'spotUplRatio': '', 'stgyEq': '0', 'totalPnl': '', 'totalPnlRatio': '', 'twap': '0', 'uTime': '1651306734794', 'upl': '', 'uplLiab': ''}, {'accAvgPx': '', 'availBal': '300', 'availEq': '', 'borrowFroz': '', 'cashBal': '300', 'ccy': 'OKB', 'clSpotInUseAmt': '', 'crossLiab': '', 'disEq': '14939.64', 'eq': '300', 'eqUsd': '16599.6', 'fixedBal': '0', 'frozenBal': '0', 'imr': '', 'interest': '', 'isoEq': '0', 'isoLiab': '', 'isoUpl': '', 'liab': '', 'maxLoan': '', 'maxSpotInUse': '', 'mgnRatio': '', 'mmr': '', 'notionalLever': '', 'openAvgPx': '', 'ordFrozen': '0', 'rewardBal': '', 'smtSyncEq': '0', 'spotBal': '', 'spotCopyTradingEq': '0', 'spotInUseAmt': '', 'spotIsoBal': '0', 'spotUpl': '', 'spotUplRatio': '', 'stgyEq': '0', 'totalPnl': '', 'totalPnlRatio': '', 'twap': '0', 'uTime': '1651306734742', 'upl': '', 'uplLiab': ''}, {'accAvgPx': '', 'availBal': '9000', 'availEq': '', 'borrowFroz': '', 'cashBal': '9000', 'ccy': 'USDT', 'clSpotInUseAmt': '', 'crossLiab': '', 'disEq': '9005.76', 'eq': '9000', 'eqUsd': '9005.76', 'fixedBal': '0', 'frozenBal': '0', 'imr': '', 'interest': '', 'isoEq': '0', 'isoLiab': '', 'isoUpl': '', 'liab': '', 'maxLoan': '', 'maxSpotInUse': '', 'mgnRatio': '', 'mmr': '', 'notionalLever': '', 'openAvgPx': '', 'ordFrozen': '0', 'r ...

# %% [markdown]
# ## Get available trading pairs from [Get instruments](https://www.okx.com/docs-v5/en/#rest-api-public-data-get-instruments).

# %%
import okx.PublicData as PublicData

flag = "1"  # live trading: 0, demo trading: 1

PublicDataAPI = PublicData.PublicAPI(flag=flag)

result = PublicDataAPI.get_instruments(
   instType="SPOT"
)
print(result)
# Out:
# 2024-12-12 11:14:13.362 | DEBUG    | okx.utils:get_header_no_sign:39 - header: {'Content-Type': 'application/json', 'x-simulated-trading': '1'}
# 2024-12-12 11:14:13.363 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:14:13.363 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/public/instruments?instType=SPOT
# 2024-12-12 11:14:13.364 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '0', 'data': [{'alias': '', 'auctionEndTime': '', 'baseCcy': 'BTC', 'category': '1', 'ctMult': '', 'ctType': '', 'ctVal': '', 'ctValCcy': '', 'expTime': '', 'instFamily': '', 'instId': 'BTC-USD', 'instType': 'SPOT', 'lever': '', 'listTime': '1733136000000', 'lotSz': '0.00000001', 'maxIcebergSz': '9999999999.0000000000000000', 'maxLmtAmt': '1000000', 'maxLmtSz': '9999999999', 'maxMktAmt': '1000000', 'maxMktSz': '1000000', 'maxStopSz': '1000000', 'maxTriggerSz': '9999999999.0000000000000000', 'maxTwapSz': '9999999999.0000000000000000', 'minSz': '0.00001', 'optType': '', 'quoteCcy': 'USD', 'ruleType': 'normal', 'settleCcy': '', 'state': 'live', 'stk': '', 'tickSz': '0.1', 'uly': ''}, {'alias': '', 'auctionEndTime': '', 'baseCcy': 'USDT', 'category': '1', 'ctMult': '', 'ctType': '', 'ctVal': '', 'ctValCcy': '', 'expTime': '', 'instFamily': '', 'instId': 'USDT-USD', 'instType': 'SPOT', 'lever': '', 'listTime': '1733132400000', 'lotSz': '0.0001', 'maxIcebergSz': '99999999999999.0000000000000000', 'maxLmtAmt': '1000000', 'maxLmtSz': '99999999999999', 'maxMktAmt': '1000000', 'maxMktSz': '1000000', 'maxStopSz': '1000000', 'maxTriggerSz': '99999999999999.0000000000000000', 'maxTwapSz': '99999999999999.0000000000000000', 'minSz': '1', 'optType': '', 'quoteCcy': 'USD', 'ruleType': 'normal', 'settleCcy': '', 'state': 'live', 'stk': '', 'tickSz': '0.0001', 'uly': ''}, {'alias': '', 'auctionEndTime': '', 'baseCcy': 'USDT', 'category': '1', 'ctMult': '', 'ctType': '', 'ctVal': '', 'ctValCcy': '', 'expTime': '', 'instFamily': '', 'instId': 'USDT-AUD', 'instType': 'SPOT', 'lever': '', 'listTime': '1721829000000', 'lotSz': '0.0001', 'maxIcebergSz': '9999999999999.0000000000000000', 'maxLmtAmt': '1000000', 'maxLmtSz': '9999999999999', 'maxMktAmt': '1000000', 'maxMktSz': '1000000', 'maxStopSz': '1000000', 'maxTriggerSz': '9999999999999.0000000000000000', 'maxTwapSz': '9999999999999.0000000000000000', 'minSz': '0.1', 'optType': '', 'quoteCcy': 'AUD', 'ruleType': 'normal', 'settleCcy': '', 'state': 'live', 'stk': '', 'tickSz': '0.0001', 'uly': ''}, {'alias': '', 'auctionEndTime': '', 'baseCcy': 'BTC', 'category': '1', 'ctMult': '', 'ctType': '', 'ctVal': '', 'ctValCcy': '', 'expTime': '', 'instFamily': '', 'instId': 'BTC-AED', 'instType': 'SPOT', 'lever': '', 'listTime': '1716780000000', 'lotSz': '0.000000001', 'maxIcebergSz': '999999999.0000000000000000', 'maxLmtAmt': '1000000', 'maxLmtSz': '999999999', 'maxMktAmt': '1000000', 'maxMktSz': '1000000', 'maxStopSz': '1000000', 'maxTriggerSz': '999999999.0000000000000000', 'maxTwapSz': '999999999.0000000000000000', 'minSz': '0.000001', 'optType': '', 'quoteCcy': 'AED', 'ruleType': 'normal', 'settleCcy': '', 'state': 'live', 'stk': '', 'tickSz': '1', 'uly': ''}, {'alias': '', 'auctionEndTime': '', 'baseCcy': 'ETH', 'category': '1', 'ctMult': '', 'ctType': '', 'ctVal': '', 'ctValCcy': '', 'expTime': '', 'instFamily': '', 'instId': 'ETH-AED', 'instType': 'SPOT', 'lever': '', 'listTime': '1716780180000', 'lotSz': '0.0000001', 'maxIcebergSz': '99999999999.0000000000000000', 'maxLmtAmt': '1000000', 'maxLmtSz': '99999999999', 'maxMktAmt': '1000000', 'maxMktSz': '1000000', 'maxStopSz': '1000000', 'maxTriggerSz': '99999999999.0000000000000000', 'maxTwapSz': '99999999999.0000000000000000', 'minSz': '0.0001', 'optType': '', 'quoteCcy': 'AED', 'ruleType': 'normal', 'settleCcy': '', 'state': 'live', 'stk': '', 'tickSz': '1', 'uly': ''}, {'alias': '', 'auctionEndTime': '', 'baseCcy': 'USDT', 'category': '1', 'ctMult': '', 'ctType': '', 'ctVal': '', 'ctValCcy': '', 'expTime': '', 'instFamily': '', 'instId': 'USDT-AED', 'instType': 'SPOT', 'lever': '', 'listTime': '1716779100000', 'lotSz': '0.00001', 'maxIcebergSz': '9999999999999.0000000000000000', 'maxLmtAmt': '1000000', 'maxLmtSz': '9999999999999', 'maxMktAmt': '1000000', 'maxMktSz': '1000000', 'maxStopSz': '1000000', 'maxTriggerSz': '9999999999999.0000000000000000', 'maxTwapSz': '9999999999999.0000000000000000', 'minSz': '0.1', 'optType': '', 'quoteCcy': ' ...

# %% [markdown]
# ## Make sure you have enough funds to trade a certain pair. Please refer to [Get maximum tradable amount](https://www.okx.com/docs-v5/en/#rest-api-account-get-maximum-available-tradable-amount)

# %%
import okx.Account as Account

flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)

result = accountAPI.get_max_avail_size(
    instId="BTC-USDT",
    tdMode="cash"
)
print(result)
# Out:
# 2024-12-12 11:14:38.226 | DEBUG    | okx.utils:pre_hash:18 - body:
# 2024-12-12 11:14:38.226 | DEBUG    | okx.utils:get_header:31 - header: {'Content-Type': 'application/json', 'OK-ACCESS-KEY': '80791c49-301a-401e-9e5a-5ec357eaacc9', 'OK-ACCESS-SIGN': b'ypGAliHbS15ykwRBLYRoEAMBZ0uZP2q0pgiQ0ccXqL4=', 'OK-ACCESS-TIMESTAMP': '2024-12-12T03:14:38.226Z', 'OK-ACCESS-PASSPHRASE': 'Robin3910!', 'x-simulated-trading': '1'}
# 2024-12-12 11:14:38.227 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:14:38.227 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/account/max-avail-size?instId=BTC-USDT&tdMode=cash
# 2024-12-12 11:14:38.227 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '0', 'data': [{'availBuy': '9000', 'availSell': '3', 'instId': 'BTC-USDT'}], 'msg': ''}

# %%
import okx.Account as Account

flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)

result = accountAPI.get_max_avail_size(
    instId="BTC-USDT",
    tdMode="cash"
)
print(result)
# Out:
# 2024-12-12 11:14:54.314 | DEBUG    | okx.utils:pre_hash:18 - body:
# 2024-12-12 11:14:54.314 | DEBUG    | okx.utils:get_header:31 - header: {'Content-Type': 'application/json', 'OK-ACCESS-KEY': '80791c49-301a-401e-9e5a-5ec357eaacc9', 'OK-ACCESS-SIGN': b'66UL1a5JUs/0t3dCQk9tMjbXWe80uU+LeAK+qEnsjsQ=', 'OK-ACCESS-TIMESTAMP': '2024-12-12T03:14:54.313Z', 'OK-ACCESS-PASSPHRASE': 'Robin3910!', 'x-simulated-trading': '1'}
# 2024-12-12 11:14:54.314 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:14:54.315 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/account/max-avail-size?instId=BTC-USDT&tdMode=cash
# 2024-12-12 11:14:54.315 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '0', 'data': [{'availBuy': '9000', 'availSell': '3', 'instId': 'BTC-USDT'}], 'msg': ''}

# %% [markdown]
# ## In unified account, you can trade Spot under simple, single currency, multi currency and portfolio margin account mode. Please refer to [Introduction on Unified Account](https://www.okx.com/support/hc/en-us/articles/360054690791-1-统一交易账户介绍)

# %% [markdown]
# ## Get the current account configuration from the `acctLv` parameter in [Get account configuration](https://www.okx.com/docs-v5/en/#rest-api-account-get-account-configuration).

# %%
import okx.Account as Account

flag = "1"  # live trading: 0, demo trading: 1

accountAPI = Account.AccountAPI(api_key, secret_key, passphrase, False, flag)
result = accountAPI.get_account_config()
print(result)

if result['code'] == "0":
    acctLv = result["data"][0]["acctLv"]
    if acctLv == "1":
        print("Simple mode")
    elif acctLv == "2":
        print("Single-currency margin mode")
    elif acctLv == "3":
        print("Multi-currency margin mode")
    elif acctLv == "4":
        print("Portfolio margin mode")
# Out:
# 2024-12-12 11:25:40.707 | DEBUG    | okx.utils:pre_hash:18 - body:
# 2024-12-12 11:25:40.708 | DEBUG    | okx.utils:get_header:31 - header: {'Content-Type': 'application/json', 'OK-ACCESS-KEY': '80791c49-301a-401e-9e5a-5ec357eaacc9', 'OK-ACCESS-SIGN': b'daclYQbmIJwG5cFbsmnsWRIWRSxI+uI0vGECIuIzzL8=', 'OK-ACCESS-TIMESTAMP': '2024-12-12T03:25:40.707Z', 'OK-ACCESS-PASSPHRASE': 'Robin3910!', 'x-simulated-trading': '1'}
# 2024-12-12 11:25:40.708 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:25:40.708 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/account/config
# 2024-12-12 11:25:40.708 | DEBUG    | okx.okxclient:_request:44 - body:
# {'code': '0', 'data': [{'acctLv': '1', 'acctStpMode': 'cancel_maker', 'autoLoan': False, 'ctIsoMode': 'automatic', 'enableSpotBorrow': False, 'greeksType': 'PA', 'ip': '', 'kycLv': '2', 'label': 'robin_demo', 'level': 'Lv1', 'levelTmp': '', 'liquidationGear': '-1', 'mainUid': '306364803054758409', 'mgnIsoMode': 'automatic', 'opAuth': '0', 'perm': 'read_only,trade', 'posMode': 'long_short_mode', 'roleType': '0', 'spotBorrowAutoRepay': False, 'spotOffsetType': '', 'spotRoleType': '0', 'spotTraderInsts': [], 'traderInsts': [], 'type': '0', 'uid': '306364803054758409'}], 'msg': ''}
# Simple mode

# %% [markdown]
# # Start Spot Trading

# %% [markdown]
# ### Spot trading under simple/single-currency margin mode

# %%
import okx.Trade as Trade

flag = "1"  # live trading: 0, demo trading: 1

tradeAPI = Trade.TradeAPI(api_key, secret_key, passphrase, False, flag)

# %% [markdown]
# #### place a limit order

# %%
# limit order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="limit",
    px="90000",
    sz="0.01"
)
print(result)

if result["code"] == "0":
    print("Successful order request，order_id = ",result["data"][0]["ordId"])
else:
    print("Unsuccessful order request，error_code = ",result["data"][0]["sCode"], ", Error_message = ", result["data"][0]["sMsg"])
# Out:
# 2024-12-12 11:26:27.496 | DEBUG    | okx.utils:pre_hash:18 - body: {"instId": "BTC-USDT", "tdMode": "cash", "side": "buy", "ordType": "limit", "sz": "0.01", "ccy": "", "clOrdId": "", "tag": "", "posSide": "", "px": "90000", "reduceOnly": "", "tgtCcy": "", "tpTriggerPx": "", "tpOrdPx": "", "slTriggerPx": "", "slOrdPx": "", "tpTriggerPxType": "", "slTriggerPxType": "", "quickMgnType": "", "stpId": "", "stpMode": "", "attachAlgoOrds": null}
# 2024-12-12 11:26:27.497 | DEBUG    | okx.utils:get_header:31 - header: {'Content-Type': 'application/json', 'OK-ACCESS-KEY': '80791c49-301a-401e-9e5a-5ec357eaacc9', 'OK-ACCESS-SIGN': b'glqjFOv8RdkkzGo+2zwTqFOSyR05vQtPQLuSlMOZGW4=', 'OK-ACCESS-TIMESTAMP': '2024-12-12T03:26:27.496Z', 'OK-ACCESS-PASSPHRASE': 'Robin3910!', 'x-simulated-trading': '1'}
# 2024-12-12 11:26:27.498 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:26:27.498 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/trade/order
# 2024-12-12 11:26:27.499 | DEBUG    | okx.okxclient:_request:44 - body:{"instId": "BTC-USDT", "tdMode": "cash", "side": "buy", "ordType": "limit", "sz": "0.01", "ccy": "", "clOrdId": "", "tag": "", "posSide": "", "px": "90000", "reduceOnly": "", "tgtCcy": "", "tpTriggerPx": "", "tpOrdPx": "", "slTriggerPx": "", "slOrdPx": "", "tpTriggerPxType": "", "slTriggerPxType": "", "quickMgnType": "", "stpId": "", "stpMode": "", "attachAlgoOrds": null}
# {'code': '0', 'data': [{'clOrdId': '', 'ordId': '2062644214370537472', 'sCode': '0', 'sMsg': 'Order placed', 'tag': '', 'ts': '1733973987847'}], 'inTime': '1733973987846743', 'msg': '', 'outTime': '1733973987850273'}
# Successful order request，order_id =  2062644214370537472

# %% [markdown]
# #### place a market order

# %%
#  market order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="market",
    sz="100",
)
print(result)
# Out:
# 2024-12-12 11:27:19.903 | DEBUG    | okx.utils:pre_hash:18 - body: {"instId": "BTC-USDT", "tdMode": "cash", "side": "buy", "ordType": "market", "sz": "100", "ccy": "", "clOrdId": "", "tag": "", "posSide": "", "px": "", "reduceOnly": "", "tgtCcy": "", "tpTriggerPx": "", "tpOrdPx": "", "slTriggerPx": "", "slOrdPx": "", "tpTriggerPxType": "", "slTriggerPxType": "", "quickMgnType": "", "stpId": "", "stpMode": "", "attachAlgoOrds": null}
# 2024-12-12 11:27:19.904 | DEBUG    | okx.utils:get_header:31 - header: {'Content-Type': 'application/json', 'OK-ACCESS-KEY': '80791c49-301a-401e-9e5a-5ec357eaacc9', 'OK-ACCESS-SIGN': b'WpHomz5pKiJ/4Ct+lRLGZj9Tpz754SWEMt6wZVSNXnU=', 'OK-ACCESS-TIMESTAMP': '2024-12-12T03:27:19.903Z', 'OK-ACCESS-PASSPHRASE': 'Robin3910!', 'x-simulated-trading': '1'}
# 2024-12-12 11:27:19.904 | DEBUG    | okx.okxclient:_request:42 - domain: https://www.okx.com
# 2024-12-12 11:27:19.905 | DEBUG    | okx.okxclient:_request:43 - url: /api/v5/trade/order
# 2024-12-12 11:27:19.905 | DEBUG    | okx.okxclient:_request:44 - body:{"instId": "BTC-USDT", "tdMode": "cash", "side": "buy", "ordType": "market", "sz": "100", "ccy": "", "clOrdId": "", "tag": "", "posSide": "", "px": "", "reduceOnly": "", "tgtCcy": "", "tpTriggerPx": "", "tpOrdPx": "", "slTriggerPx": "", "slOrdPx": "", "tpTriggerPxType": "", "slTriggerPxType": "", "quickMgnType": "", "stpId": "", "stpMode": "", "attachAlgoOrds": null}
# {'code': '0', 'data': [{'clOrdId': '', 'ordId': '2062645973226754048', 'sCode': '0', 'sMsg': 'Order placed', 'tag': '', 'ts': '1733974040265'}], 'inTime': '1733974040264357', 'msg': '', 'outTime': '1733974040267030'}

# %% [markdown]
# #### place an order with tgtCcy=quote_ccy (only applicable to spot)

# %%
#  market order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="market",
    sz="100",
    tgtCcy="quote_ccy" # this determines the unit of the sz parameter. base_ccy is the default value
)
print(result)

# %% [markdown]
# #### place an order with your own clOrdId

# %%
#  market order
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",
    ordType="market",
    sz="100",
    clOrdId="003" # you can define your own client defined order ID
)
print(result)

# %% [markdown]
# ### Spot trading under multi-currency/porfolio margin mode

# %%
# cross-margin spot trading
result = tradeAPI.place_order(
    instId="BTC-USDT",
    tdMode="cross",
    side="buy",
    ordType="limit",
    px="1000",
    sz="0.01"
)
print(result)

if result["code"] == "0":
    print("Successful order request，order_id = ",result["data"][0]["ordId"])
else:
    print("Unsuccessful order request，error_code = ",result["data"][0]["sCode"], ", Error_message = ", result["data"][0]["sMsg"])

# %% [markdown]
# ### For additional information on the place order endpoint，please refer to [Place order](https://www.okx.com/docs-v5/en/#rest-api-trade-place-order)
#
# ### To place orders in a batch, please refer to [Get account configuration](https://www.okx.com/docs-v5/en/#rest-api-trade-place-multiple-orders)

# %%
place_orders = [
    {"instId":"BTC-USDT", "tdMode":"cash", "side":"buy", "ordType" : "limit","px":"1000","sz":"0.01"},
    {"instId": "BTC-USDT", "tdMode": "cash", "side": "buy", "ordType": "limit", "px": "1000", "sz": "0.02"}
]

result = tradeAPI.place_multiple_orders(place_orders)
print(result)

# %% [markdown]
# ### To amend pending orders，please refer to [Amend order](https://www.okx.com/docs-v5/en/#rest-api-trade-amend-order)

# %%
result = tradeAPI.amend_order(
    instId="BTC-USDT",
    ordId="489103565508685824",
    newSz="0.012"
)
print(result)

# %% [markdown]
# ### To amend orders in a batch, please refer to [Amend multiple orders](https://www.okx.com/docs-v5/en/#rest-api-trade-amend-multiple-orders)

# %%
amend_orders = [
    {"instId": "BTC-USDT", "ordId": "489106394289909760","newSz":"0.001"},
    {"instId": "BTC-USDT", "ordId": "489106394289909761","newSz":"0.001"},
]

result = tradeAPI.amend_multiple_orders(amend_orders)
print(result)

# %% [markdown]
# ### To cancel pending orders，please refer to [Cancel order](https://www.okx.com/docs-v5/en/#rest-api-trade-cancel-order)

# %%
result = tradeAPI.cancel_order(instId="BTC-USDT", ordId = "489093931993509888")
print(result)

# %% [markdown]
# ### To cancel orders in a batch，please refer to [Cancel multiple orders](https://www.okx.com/docs-v5/zh/#rest-api-trade-cancel-multiple-orders)

# %%
cancel_orders = [
    {"instId": "BTC-USDT", "ordId": "489102222534488064"},
    {"instId": "BTC-USDT", "ordId": "489102222534488065"},
]

result = tradeAPI.cancel_multiple_orders(cancel_orders)
print(result)

# %% [markdown]
# ## Get details of a certain order, please refer to [Get order details](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-details)

# %%
result = tradeAPI.get_order(instId="BTC-USDT", clOrdId="002")
print(result)

# %%
result = tradeAPI.get_order(instId="BTC-USDT", ordId="497819823594909696")
print(result)

# %% [markdown]
# ## To get the list of open orders，please refer to [Get order List](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-list)

# %%
result = tradeAPI.get_order_list()
print(result)

# %% [markdown]
# ### To get past orders，please refer to [Get order history (last 7 days）](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-history-last-7-days) and [Get order history (last 3 months)](https://www.okx.com/docs-v5/en/#rest-api-trade-get-order-history-last-3-months)

# %%
result = tradeAPI.get_orders_history(
    instType="SPOT"
)
print(result)

# %%
result = tradeAPI.get_orders_history_archive(
    instType="SPOT"
)
print(result)

# %% [markdown]
# ### To get past trades，please refer to [Get transaction details (last 3 days）](https://www.okx.com/docs-v5/en/#rest-api-trade-get-transaction-details-last-3-days) and [Get transaction details (last 3 months) ](https://www.okx.com/docs-v5/en/#rest-api-trade-get-transaction-details-last-3-months)

# %%
result = tradeAPI.get_fills(
    instType="SPOT"
)
print(result)

# %%
result = tradeAPI.get_fills_history(
    instType="SPOT"
)
print(result)

# %% [markdown]
# ### If you wish to place orders when the price reaches a certain level, you can place an algo order

# %%
result = tradeAPI.place_algo_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="buy",             # buy
    ordType="trigger",      # order type
    sz="100",               # order amount: 100USDT
    triggerPx="10000",      # trigger price
    orderPx="-1",           # order price. When orderPx=-1, the order will be placed as an market order
    triggerPxType="last"    # trigger price type。last：last trade price
)
print(result)

# %% [markdown]
# ## You can also use Stop Loss or Take Profit order to sell the currencies in your account

# %%
result = tradeAPI.place_algo_order(
    instId="BTC-USDT",
    tdMode="cash",
    side="sell",                # sell
    ordType="conditional",      # one-way take profit or stop loss
    sz="0.01",               # order amount: 0.01BTC
    tpTriggerPx="30000",      # take profit trigger price
    tpOrdPx="-1",           # taker profit order price。When it is set to -1，the order will be placed as an market order
    tpTriggerPxType="last"    # take profit trigger price type。last：last trade price
)
print(result)

# %% [markdown]
# ### For additional information, please refer to  [Place algo order](https://www.okx.com/docs-v5/en/#rest-api-trade-place-algo-order)

# %% [markdown]
# ### Cancel pending algo orders (not including Iceberg order, TWAP order, Trailing Stop order)，please refer to [Cancel algo order](https://www.okx.com/docs-v5/en/#rest-api-trade-cancel-algo-order)

# %%
algo_orders = [
    {"instId": "BTC-USDT", "algoId": "495001187587043328"},
]

result = tradeAPI.cancel_algo_order(algo_orders)
print(result)

# %% [markdown]
# ### To get list of currently pending algo orders，please refer to [Get algo order list](https://www.okx.com/docs-v5/en/#rest-api-trade-get-algo-order-list)

# %%
result = tradeAPI.order_algos_list(
    ordType="trigger"     # order type
)
print(result)

# %% [markdown]
# ### To get the past algo orders (last three months)，please refer to [Get algo order history](https://www.okx.com/docs-v5/en/#rest-api-trade-get-algo-order-history)

# %%
result = tradeAPI.order_algos_history(
    ordType="conditional",     # order type
    state="canceled"           # state of the orders
)
print(result)
